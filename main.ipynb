# %% [markdown]
# ## Setup

# %%
# Allows us to edit submodules on the fly without needing to restart kernel
# %load_ext autoreload
# %autoreload 2

# %%
import os
os.environ["OMP_NUM_THREADS"] = "4"  # Safe and stable, avoid MKL memory leak on Windows when backtesting

# %%
# Imports
from common_imports import *
from api_init import initialize_apis
from data_extraction import get_continuous_risk_free_rate, get_live_ric_data
from testing import split_train_test_calendar_window, compare_simulated_to_real_returns, run_rolling_volatility_regime_model
from plotting import *
from branding import *
from models.gbm import monte_carlo_paths_gbm
from models.jump import monte_carlo_paths_jumps, calibrate_jump_model
from models.regime import monte_carlo_paths_regimes, calibrate_volatility_regime_model
from models.heston import monte_carlo_paths_heston, calibrate_heston_model

# %%
# Constants
PRICE = 5000 # In real time, this is equal to (bid+ask)/2 = mid-price
SIGMA = 0.2 # Annualised volatility
R = 0.04 # CONTINUOUS risk-free rate proxy for 1 year
Q = 0.01 # CONTINUOUS dividend yield of the asset
T = 1.0 # 1 year
STEPS = 252 # Assume simulation is for 1 trading year
N_PATHS = 100_000 # For all but the regime models, this number should be >= 100,000. The regime model should be lower
RIC = 'SPY' # The default asset to analyse
OPTION_RIC = 'SPYATMIV.U' # Options of an asset are a different asset class in Refinitiv
WINDOW = 63 # The number of days in 3 trading months
EXPECTED_RETURN = 0.0651637109089667 # Expected Return of the S&P500 according to Actinver on 02/01/2024
SEED = 42 # Ensures consistency in results
FONT = 'Century Gothic' # Default Actinver font
KNOCK_IN = 0.8
AC_TRIGGER = 1.0
sns.set_palette(COLOR_CYCLE) # Sets colours of graphs to be Actinver colors

# %%
# API set-up 
fred, eikon = initialize_apis()

# %% [markdown]
# ## Extraction

# %%
# Gets the current values of input for our models - only run if you want live data
r, _, _ = get_continuous_risk_free_rate(fred)
S0, sigma, q = get_live_ric_data(RIC, OPTION_RIC)

# %%
# Read README for more details on this database
historic_data = pd.read_excel("Data/historic_data_spx.xlsx")
historic_data["Date"] = pd.to_datetime(historic_data["Date"])
historic_data = historic_data.set_index("Date")
historic_data_prices = historic_data['Price']

# %%
# Split into train and test
train_data, test_data = split_train_test_calendar_window(historic_data, 
                                      test_start_date='01/01/2024', 
                                      train_years=5, 
                                      date_column='Date')

# %%
# Main
train_price_series = train_data['Price']
test_price_series = test_data['Price']

# Define initial parameters
S0 = train_data['Price'].iloc[-1]            # Last observed price before simulation, last price of the training date
q  = train_data['Div'].iloc[-1]              # Last dividend yield
r  = train_data['Risk_Free'].iloc[-1]        # Last risk-free rate
expected_return = train_data['Actinver_Expected_Return'].iloc[-1] # Last expected return
last_train_date = train_data.index[-1] # The simulation should start ON the first day of the train set, which means it's initial starting point is the last_train_date

# Prepend last_train_date to test_dates for the graphing 
paths_dates = pd.concat([pd.Series([last_train_date]), pd.Series(test_data.index)], ignore_index=True)

# %% [markdown]
# ## Models

# %%
# GBM, standard vanilla one
gbm_paths = monte_carlo_paths_gbm(
    S0=S0, q=q, r=r, expected_return=expected_return,
    sigma=SIGMA, T=T, steps=STEPS, n_paths=N_PATHS,
    measure='Real', seed=SEED
)
# Out:
# Simulating GBM Paths: 100%|█████████████████████████████████████████████████████████| 252/252 [00:01<00:00, 180.99it/s]

# %%
# Jumps, worst performing one thus far
jump_sigma, lambda_j, m_j, s_j, jumps = calibrate_jump_model(train_price_series)

jump_paths = monte_carlo_paths_jumps(
    S0=S0,   # start at the most recent price
    q=q,                     # dividend yield
    r=r,                     # risk-free rate
    expected_return=expected_return,       # real-world drift if measure='Real'
    T=1.0,                        # 1 year
    steps=STEPS,                  # daily steps
    n_paths=N_PATHS,              # number of paths
    sigma=jump_sigma,             # diffusion volatility from calibration
    lambda_j=lambda_j,          # jump intensity
    m_j=m_j,                    # mean log jump size
    s_j=s_j,                    # std dev log jump size
    measure='Real',             # or 'Real'
    seed=SEED                     # for reproducibility
)

# %%
# Volatility regime switching, best performing one thus far, but also, the slowest, at 1,000,000 paths it takes 44 seconds per iteration and needs to do 252 for a year, so it would take 3 hours
sigmas, transition_matrix_df, regimes_series = calibrate_volatility_regime_model(
    price_series=train_price_series,
    n_regimes=4,               
    annualize=True,
    verbose=True,
    export_excel=True
)

regime_paths, regimes = monte_carlo_paths_regimes(S0, q, r, expected_return, T, STEPS, 10_000,
                                          sigmas, transition_matrix_df,
                                          measure='Real',
                                          init_probs=None,
                                          seed=SEED)

np.savez_compressed(
    "regime_mc_simulation.npz",
    regime_paths=regime_paths,
    regimes=regimes
)

# %% [markdown]
# Regarding the number of regimes:
#
# 2 regimes provided poor performance
#
# 3 regimes performed exceptionally well
#
# 4 regimes may be overfitting
#
# 5 regimes delivered good but less robust results than 3
#
# These results were obtained using a 5-year training window, tested on data from the year 2024. Again, one might argue the validity, but speed is king. We can try more regimes if time allows

# %%
v0, kappa, theta, sigma_v, rho = calibrate_heston_model(train_price_series)

heston_paths, v_paths = monte_carlo_paths_heston(
    S0=S0,     # Start from most recent price
    q=q,                       # Dividend yield
    r=r,                       # Risk-free rate
    expected_return=expected_return,         # If using 'Real' measure
    T=T,                        # 1 year horizon
    steps=STEPS,                    # Daily steps
    n_paths=N_PATHS,                # Number of paths
    v0=0.02,                        # From calibration
    kappa=4,
    theta=0.02,
    sigma_v=0.35,
    rho=-0.7,
    measure='Real',       # or 'Real'
    seed=SEED
)

# %% [markdown]
# ## Additional Tests

# %%
max_iterations = 10_000  # safety cap
threshold = 0.05  # significance level

count = 0
ks_pval = 0  # initialize with a non-significant p-val

while ks_pval < threshold and count < max_iterations:
    ks_stat, ks_pval, ad_stat, ad_sig_level, log_returns_sim_flat = compare_simulated_to_real_returns(
        real_prices=test_price_series,
        simulated_paths=jump_paths,
        asset_name="SPX",
        verbose=None,
        seed=None
    )

    count += 1
    print(ks_pval)

print(f"Stopped after {count} iterations")
print(f"Final KS p-value: {ks_pval:.6f}")

# %% [markdown]
# Note: We simulate over 100,000 paths, which produces millions of individual return observations. Running a KS test directly between this large simulated sample and the comparatively small real return series (251 points) would lead to an unbalanced comparison and increase the risk of spurious significance purely due to sample size differences.
#
# To address this, the code randomly samples 251 log returns from the full set of simulated returns, matching the number of real observations. This process is repeated 100 times with different random seeds to capture variability. In 91 out of 100 trials, the Kolmogorov–Smirnov (KS) test produced a p-value above 0.05, indicating that we could not reject the null hypothesis that real and simulated returns come from the same distribution.
#
# In parallel, we also applied the Anderson–Darling (AD) k-sample test, which is more sensitive to discrepancies in the tails of the distribution. In some cases where the KS test did not reject the null, the AD test did, suggesting potential mismatches in extreme-value behavior (fat tails, skewness, or kurtosis) that are not captured by the KS test alone.
#
# Given time constraints, we adopted this bootstrapped KS/AD testing procedure as a statistically sound approach for validating distributional similarity, with the AD test serving as a complementary diagnostic for tail accuracy.
#
# In essence, an improvement in the model would require better tail-risk modelling

# %% [markdown]
# ## Graphs and Results

# %%
plot_return_histogram_comparison(
    real_prices=test_price_series,
    simulated_paths=gbm_paths,
    asset_name="SPX",
    use_log_returns=False,
    seed=SEED,
    bins=100,
    show_title=False,
    show_axis_titles=False,
    show_legend=False,
    filename="gbm_histogram",
    fixed_xlim=(-0.1, 0.125)
)

# %%
plot_return_kde_comparison(
    real_prices=test_price_series,
    simulated_paths=gbm_paths,
    asset_name="SPX",
    use_log_returns=False,
    seed=SEED,
    show_title=False,
    show_axis_titles=False,
    show_legend=False,
    filename="gbm_kde",
    fixed_xlim=(-0.04, 0.04)
)

# %%
plot_return_qq(
    real_prices=test_price_series,
    simulated_paths=gbm_paths,
    asset_name="SPX",
    use_log_returns=False,
    seed=SEED,
    show_title=False,
    show_axis_titles=False,
    show_legend=False,
    filename="gbm_qq"
)

# %%
plot_return_ecdf_comparison(
    real_prices=test_price_series,
    simulated_paths=gbm_paths,
    asset_name="SPX",
    use_log_returns=False,
    seed=SEED,
    show_title=False,
    show_axis_titles=False,
    show_legend=False,
    filename="gbm_ecdf"
)

# %%
global_ymin, global_ymax = compute_global_ylim(gbm_paths, jump_paths, regime_paths, heston_paths,
                                              low=1, high=99)
fixed_ylim = (global_ymin, global_ymax)

# %%
plot_fan_chart(
    paths=gbm_paths,
    percentiles=[5, 25, 50, 75, 95],
    colors=sns.color_palette("Blues", n_colors=3),
    filename_prefix="gbm_fan_chart",
    line_color=GOLD_1,
    dates=paths_dates,
    show_axis_titles=False,
    fixed_ylim=fixed_ylim
)

# %% [markdown]
# ## Backtesting
# So the objective is to get some sort of Mark To Market by using the calculator we had.
# We need the lkogic so that we calibrate the volatility regime model every DAY
# Once we have the paths, we feed it into the calculator, and we backsolve for value, assuming we have a coupon:

# %%
# Create a new series just for the backtesting, i dont know
price_series_for_backtesting = pd.Series(
    data=historic_data["Price"].values,
    index=pd.to_datetime(historic_data["Date"]),
    name="Price"
)

# %%
calibration_path = 'data/rolling_4regime_calibration_S&P500.xlsx'
if os.path.exists(calibration_path):
    print("✅ Loading cached calibration results...")
    calibration_results = pd.read_excel(calibration_path, index_col="Date", parse_dates=True)
else:
    print("🚀 Running calibration...")
    calibration_results = run_rolling_volatility_regime_model(price_series_for_backtesting, 
                                                              export_excel=True, 
                                                              save_path=calibration_path)
# Out:
# ✅ Loading cached calibration results...

# %%
# Get last row of calibration
latest = calibration_results.iloc[-1]

# Extract required inputs
sigmas = [latest[f"Sigma_{i}"] for i in range(4)]  # for 4 regimes
transition_matrix = latest.filter(like="Transition_").values.reshape(4, 4)

# Market inputs
S0 = historic_data_prices.iloc[-1]
r = historic_data["Risk_Free"].iloc[-1]
q = historic_data["Div"].iloc[-1]
expected_return = 0.08

# %%
def monte_carlo_paths_regimes_with_stats(
    S0, q, r, expected_return, T, steps, n_paths,
    sigmas, transition_matrix,
    measure='Risk-Neutral',
    init_probs=None,
    seed=None,
    autocall_barrier=None,
    autocall_freq=None,
    knockin_barrier=None,
):
    """
    Simulate GBM paths with N-state volatility regime switching and compute autocall/knock-in stats.

    Returns:
    - paths: ndarray of shape (steps + 1, n_paths)
    - regimes: ndarray of shape (steps, n_paths)
    - stats: dict with autocall and knock-in metrics
    """
    if seed is not None:
        np.random.seed(seed)

    sigmas = np.asarray(sigmas)
    n_regimes = len(sigmas)
    transition_matrix = np.asarray(transition_matrix)

    if init_probs is None:
        init_probs = np.full(n_regimes, 1 / n_regimes)
    else:
        init_probs = np.asarray(init_probs)

    dt = T / steps
    mu = r - q if measure == 'Risk-Neutral' else expected_return

    paths = np.empty((steps + 1, n_paths))
    regimes = np.empty((steps, n_paths), dtype=int)

    paths[0] = S0
    current_regime = np.random.choice(n_regimes, size=n_paths, p=init_probs)
    alive = np.ones(n_paths, dtype=bool)
    autocall_flags = np.zeros(n_paths, dtype=bool)
    autocall_counts = []

    for t in range(1, steps + 1):

        # This is where the beauty happens 
        transition_probs = transition_matrix[current_regime]
        rand_draws = np.random.uniform(size=n_paths) 
        cumulative_probs = np.cumsum(transition_probs, axis=1) # Convert each path's transition probabilities into cumulative probabilities (CDF) This is required for inverse transform sampling
        next_regime = (rand_draws[:, None] < cumulative_probs).argmax(axis=1) # Determine the next regime for each path. The regime is the first one where the cumulative probability exceeds the random draw
        current_regime = next_regime
        regimes[t - 1] = current_regime

        # Standard model construction
        sigma_t = sigmas[current_regime]
        z = np.random.standard_normal(n_paths)
        drift = (mu - 0.5 * sigma_t**2) * dt
        diffusion = sigma_t * np.sqrt(dt) * z
        growth = np.exp(drift + diffusion)
        paths[t] = paths[t - 1] * growth

        if autocall_barrier is not None and autocall_freq and t % autocall_freq == 0:
            triggered = (paths[t] >= S0 * autocall_barrier) & (~autocall_flags)
            autocall_counts.append(np.sum(triggered))
            autocall_flags |= triggered
            alive[triggered] = False

        if not alive.any():
            paths[t + 1:] = np.nan
            break

    not_called = ~autocall_flags
    final_prices = paths[-1]
    barrier_abs = knockin_barrier * S0 if knockin_barrier is not None else -np.inf

    ki_mask = not_called & (final_prices <= barrier_abs)
    expected_ST_given_KI = np.mean(final_prices[ki_mask]) if np.any(ki_mask) else None
    mat_below_ki = np.sum(ki_mask)
    mat_above_ki = np.sum(not_called & (final_prices > barrier_abs))

    stats = {f"AC{i+1}": count / n_paths for i, count in enumerate(autocall_counts)}
    stats.update({
        "Maturity Above KI": mat_above_ki / n_paths,
        "Maturity Below KI": mat_below_ki / n_paths,
        "Expected ST Given KI": expected_ST_given_KI
    })

    return paths, regimes, stats

# %%
all_results = []

for date, row in tqdm(calibration_results.iterrows(), total=len(calibration_results), desc="Simulating for each date"):
    print(f"Number of results: {len(all_results)}")

    try:
        # Extract parameters for this date
        n_regimes = 4  # or infer from row
        sigmas = [row[f"Sigma_{i}"] for i in range(n_regimes)]
        transition_matrix = row.filter(like="Transition_").values.reshape(n_regimes, n_regimes)

        # Inputs for Monte Carlo
        S0 = historic_data_prices.loc[date]  # starting price that day
        r = historic_data["Risk_Free"].loc[date]
        q = historic_data["Div"].loc[date]
        expected_return = historic_data["Actinner_Expected_Return"].loc[date]  # typo fixed


        # Get last row of calibration
        latest = calibration_results.iloc[-1]
        
        # Extract required inputs
        sigmas = [latest[f"Sigma_{i}"] for i in range(4)]  # for 4 regimes
        transition_matrix = latest.filter(like="Transition_").values.reshape(4, 4)
        
        # Market inputs
        S0 = historic_data_prices.iloc[-1]
        r = historic_data["Risk_Free"].iloc[-1]
        q = historic_data["Div"].iloc[-1]
        expected_return = 0.08

        # Run regime-switching simulation
        paths, regimes, stats = monte_carlo_paths_regimes_with_stats(
            S0=S0,
            q=q,
            r=r,
            expected_return=expected_return,
            T=1.0,
            steps=252,
            n_paths=1000,  # adjust as needed
            sigmas=sigmas,
            transition_matrix=transition_matrix,
            measure="Risk-Neutral",
            seed=SEED,  # or vary with time if needed
            autocall_barrier=1.0,
            autocall_freq=None,
            knockin_barrier=0.8,
        )

        # Store summary (mean final price, std, quantiles)
        final_prices = paths[-1, :]
        all_results.append({
            "Date": date,
            "Simulated_Mean": final_prices.mean(),
            "Simulated_Std": final_prices.std(),
            "Simulated_P5": np.percentile(final_prices, 5),
            "Simulated_P95": np.percentile(final_prices, 95),
            "Simulated_Median": np.median(final_prices),
        })

        print(f"Number of results: {len(all_results)}")


    except Exception as e:
        print(f"⚠️ Skipping {date} due to error: {e}")
        continue

# Convert to DataFrame
sim_summary_df = pd.DataFrame(all_results).set_index("Date")

# %%
type(calibration_results)
# Out:
# pandas.core.frame.DataFrame

# %%
all_results = []


# date 

for date, row in tqdm(calibration_results.iterrows(), total=len(calibration_results), desc="Simulating for each date"):
    try:
        n_regimes = 4
        sigmas = [row[f"Sigma_{i}"] for i in range(n_regimes)]
        transition_matrix = row.filter(like="Transition_").values.reshape(n_regimes, n_regimes)
        S0 = price_series_for_backtesting.loc[date]
        r = 0.05
        q = 0.01
        expected_return=0.08

        print(date)

        # Run regime-switching simulation
        paths, regimes = monte_carlo_paths_regimes(
            S0=S0,
            q=q,
            r=r,
            expected_return=expected_return,
            T=1.0,
            steps=252,
            n_paths=100,
            sigmas=sigmas,
            transition_matrix=transition_matrix,
            measure="Risk-Neutral",
            seed=SEED
        )

        final_prices = paths[-1, :]
        all_results.append({
            "Date": date,
            "Simulated_Mean": final_prices.mean(),
            "Simulated_Std": final_prices.std(),
            "Simulated_P5": np.percentile(final_prices, 5),
            "Simulated_P95": np.percentile(final_prices, 95),
            "Simulated_Median": np.median(final_prices),
        })
    except Exception as e:
        print(f"⚠️ Skipping {date} due to error: {e}")
        continue

# Convert to DataFrame
sim_summary_df = pd.DataFrame(all_results).set_index("Date")

# %%
# After this, historic_data will be indexed

# %%
historic_data["Date"] = pd.to_datetime(historic_data["Date"])
historic_data_indexed = historic_data.set_index("Date")

# %%
historic_data_prices
# Out:
# 0       1283.72
# 1       1285.20
# 2       1280.09
# 3       1282.46
# 4       1270.84
#          ...
# 4852    5844.19
# 4853    5886.55
# 4854    5892.58
# 4855    5916.93
# 4856    5958.38
# Name: Price, Length: 4857, dtype: float64

# %%
all_results = []

for date, row in tqdm(calibration_results.iterrows(), total=len(calibration_results), desc="Simulating for each date"):
    try:
        n_regimes = 4
        sigmas = [row[f"Sigma_{i}"] for i in range(n_regimes)]
        transition_matrix = row.filter(like="Transition_").values.reshape(n_regimes, n_regimes)

        # Check if required market inputs exist for this date
        print(date)
        print(historic_data.index)
        if date not in historic_data_prices.index or date not in historic_data.index:
            print(f"⚠️ Skipping {date} due to missing market data")
            continue

        # Market inputs
        S0 = historic_data_prices.loc[date]
        r = historic_data["Risk_Free"].loc[date]
        q = historic_data["Div"].loc[date]
        expected_return = historic_data["Actinver_Expected_Return"].loc[date]  # or fix typo

        # Run simulation
        paths, regimes, stats = monte_carlo_paths_regimes_with_stats(
            S0=S0,
            q=q,
            r=r,
            expected_return=expected_return,
            T=1.0,
            steps=252,
            n_paths=1000,
            sigmas=sigmas,
            transition_matrix=transition_matrix,
            measure="Risk-Neutral",
            seed=SEED,
            autocall_barrier=1.0,
            autocall_freq=None,
            knockin_barrier=0.8,
        )

        print(S0, r, q, expected_return)

        # Store simulation summary
        final_prices = paths[-1, :]
        all_results.append({
            "Date": date,
            "Simulated_Mean": final_prices.mean(),
            "Simulated_Std": final_prices.std(),
            "Simulated_P5": np.percentile(final_prices, 5),
            "Simulated_P95": np.percentile(final_prices, 95),
            "Simulated_Median": np.median(final_prices),
        })

    except Exception as e:
        print(f"⚠️ Skipping {date} due to error: {e}")
        continue

# Build DataFrame
if all_results:
    sim_summary_df = pd.DataFrame(all_results).set_index("Date")
    print(sim_summary_df.head())
else:
    print("❌ No simulation results generated.")
# Out:
# Simulating for each date:  25%|██▍       | 886/3597 [00:00<00:00, 4291.93it/s]
# 2011-01-28 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-01-28 00:00:00 due to missing market data
# 2011-01-31 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-01-31 00:00:00 due to missing market data
# 2011-02-01 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-02-01 00:00:00 due to missing market data
# 2011-02-02 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-02-02 00:00:00 due to missing market data
# 2011-02-03 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-02-03 00:00:00 due to missing market data
# 2011-02-04 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-02-04 00:00:00 due to missing market data
# 2011-02-07 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-02-07 00:00:00 due to missing market data
# 2011-02-08 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-02-08 00:00:00 due to missing market data
# 2011-02-09 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-02-09 00:00:00 due to missing market data
# 2011-02-10 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-02-10 00:00:00 due to missing market data
# 2011-02-11 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-02-11 00:00:00 due to missing market data
# 2011-02-14 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-02-14 00:00:00 due to missing market data
# 2011-02-15 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-02-15 00:00:00 due to missing market data
# 2011-02-16 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-02-16 00:00:00 due to missing market data
# 2011-02-17 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-02-17 00:00:00 due to missing market data
# 2011-02-18 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-02-18 00:00:00 due to missing market data
# 2011-02-22 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-02-22 00:00:00 due to missing market data
# 2011-02-23 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-02-23 00:00:00 due to missing market data
# 2011-02-24 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-02-24 00:00:00 due to missing market data
# 2011-02-25 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-02-25 00:00:00 due to missing market data
# 2011-02-28 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-02-28 00:00:00 due to missing market data
# 2011-03-01 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-03-01 00:00:00 due to missing market data
# 2011-03-02 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-03-02 00:00:00 due to missing market data
# 2011-03-03 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-03-03 00:00:00 due to missing market data
# 2011-03-04 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-03-04 00:00:00 due to missing market data
# 2011-03-07 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-03-07 00:00:00 due to missing market data
# 2011-03-08 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-03-08 00:00:00 due to missing market data
# 2011-03-09 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-03-09 00:00:00 due to missing market data
# 2011-03-10 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-03-10 00:00:00 due to missing market data
# 2011-03-11 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-03-11 00:00:00 due to missing market data
# 2011-03-14 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-03-14 00:00:00 due to missing market data
# 2011-03-15 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-03-15 00:00:00 due to missing market data
# 2011-03-16 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-03-16 00:00:00 due to missing market data
# 2011-03-17 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-03-17 00:00:00 due to missing market data
# 2011-03-18 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-03-18 00:00:00 due to missing market data
# 2011-03-21 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-03-21 00:00:00 due to missing market data
# 2011-03-22 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-03-22 00:00:00 due to missing market data
# 2011-03-23 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-03-23 00:00:00 due to missing market data
# 2011-03-24 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-03-24 00:00:00 due to missing market data
# 2011-03-25 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-03-25 00:00:00 due to missing market data
# 2011-03-28 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-03-28 00:00:00 due to missing market data
# 2011-03-29 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-03-29 00:00:00 due to missing market data
# 2011-03-30 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-03-30 00:00:00 due to missing market data
# 2011-03-31 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-03-31 00:00:00 due to missing market data
# 2011-04-01 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-04-01 00:00:00 due to missing market data
# 2011-04-04 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-04-04 00:00:00 due to missing market data
# 2011-04-05 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-04-05 00:00:00 due to missing market data
# 2011-04-06 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-04-06 00:00:00 due to missing market data
# 2011-04-07 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-04-07 00:00:00 due to missing market data
# 2011-04-08 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-04-08 00:00:00 due to missing market data
# 2011-04-11 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-04-11 00:00:00 due to missing market data
# 2011-04-12 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-04-12 00:00:00 due to missing market data
# 2011-04-13 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-04-13 00:00:00 due to missing market data
# 2011-04-14 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-04-14 00:00:00 due to missing market data
# 2011-04-15 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-04-15 00:00:00 due to missing market data
# 2011-04-18 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-04-18 00:00:00 due to missing market data
# 2011-04-19 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-04-19 00:00:00 due to missing market data
# 2011-04-20 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-04-20 00:00:00 due to missing market data
# 2011-04-21 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-04-21 00:00:00 due to missing market data
# 2011-04-25 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-04-25 00:00:00 due to missing market data
# 2011-04-26 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-04-26 00:00:00 due to missing market data
# 2011-04-27 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-04-27 00:00:00 due to missing market data
# 2011-04-28 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-04-28 00:00:00 due to missing market data
# 2011-04-29 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-04-29 00:00:00 due to missing market data
# 2011-05-02 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-05-02 00:00:00 due to missing market data
# 2011-05-03 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-05-03 00:00:00 due to missing market data
# 2011-05-04 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-05-04 00:00:00 due to missing market data
# 2011-05-05 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-05-05 00:00:00 due to missing market data
# 2011-05-06 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-05-06 00:00:00 due to missing market data
# 2011-05-09 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-05-09 00:00:00 due to missing market data
# 2011-05-10 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-05-10 00:00:00 due to missing market data
# 2011-05-11 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-05-11 00:00:00 due to missing market data
# 2011-05-12 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-05-12 00:00:00 due to missing market data
# 2011-05-13 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-05-13 00:00:00 due to missing market data
# 2011-05-16 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-05-16 00:00:00 due to missing market data
# 2011-05-17 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-05-17 00:00:00 due to missing market data
# 2011-05-18 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-05-18 00:00:00 due to missing market data
# 2011-05-19 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-05-19 00:00:00 due to missing market data
# 2011-05-20 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-05-20 00:00:00 due to missing market data
# 2011-05-23 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-05-23 00:00:00 due to missing market data
# 2011-05-24 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-05-24 00:00:00 due to missing market data
# 2011-05-25 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-05-25 00:00:00 due to missing market data
# 2011-05-26 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-05-26 00:00:00 due to missing market data
# 2011-05-27 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-05-27 00:00:00 due to missing market data
# 2011-05-31 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-05-31 00:00:00 due to missing market data
# 2011-06-01 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-06-01 00:00:00 due to missing market data
# 2011-06-02 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-06-02 00:00:00 due to missing market data
# 2011-06-03 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-06-03 00:00:00 due to missing market data
# 2011-06-06 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-06-06 00:00:00 due to missing market data
# 2011-06-07 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-06-07 00:00:00 due to missing market data
# 2011-06-08 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-06-08 00:00:00 due to missing market data
# 2011-06-09 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-06-09 00:00:00 due to missing market data
# 2011-06-10 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-06-10 00:00:00 due to missing market data
# 2011-06-13 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-06-13 00:00:00 due to missing market data
# 2011-06-14 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-06-14 00:00:00 due to missing market data
# 2011-06-15 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-06-15 00:00:00 due to missing market data
# 2011-06-16 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-06-16 00:00:00 due to missing market data
# 2011-06-17 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-06-17 00:00:00 due to missing market data
# 2011-06-20 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-06-20 00:00:00 due to missing market data
# 2011-06-21 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-06-21 00:00:00 due to missing market data
# 2011-06-22 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-06-22 00:00:00 due to missing market data
# 2011-06-23 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-06-23 00:00:00 due to missing market data
# 2011-06-24 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-06-24 00:00:00 due to missing market data
# 2011-06-27 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-06-27 00:00:00 due to missing market data
# 2011-06-28 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-06-28 00:00:00 due to missing market data
# 2011-06-29 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-06-29 00:00:00 due to missing market data
# 2011-06-30 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-06-30 00:00:00 due to missing market data
# 2011-07-01 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-07-01 00:00:00 due to missing market data
# 2011-07-05 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-07-05 00:00:00 due to missing market data
# 2011-07-06 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-07-06 00:00:00 due to missing market data
# 2011-07-07 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-07-07 00:00:00 due to missing market data
# 2011-07-08 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-07-08 00:00:00 due to missing market data
# 2011-07-11 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-07-11 00:00:00 due to missing market data
# 2011-07-12 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-07-12 00:00:00 due to missing market data
# 2011-07-13 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-07-13 00:00:00 due to missing market data
# 2011-07-14 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-07-14 00:00:00 due to missing market data
# 2011-07-15 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-07-15 00:00:00 due to missing market data
# 2011-07-18 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-07-18 00:00:00 due to missing market data
# 2011-07-19 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-07-19 00:00:00 due to missing market data
# 2011-07-20 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-07-20 00:00:00 due to missing market data
# 2011-07-21 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-07-21 00:00:00 due to missing market data
# 2011-07-22 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-07-22 00:00:00 due to missing market data
# 2011-07-25 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-07-25 00:00:00 due to missing market data
# 2011-07-26 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-07-26 00:00:00 due to missing market data
# 2011-07-27 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-07-27 00:00:00 due to missing market data
# 2011-07-28 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-07-28 00:00:00 due to missing market data
# 2011-07-29 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-07-29 00:00:00 due to missing market data
# 2011-08-01 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-08-01 00:00:00 due to missing market data
# 2011-08-02 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-08-02 00:00:00 due to missing market data
# 2011-08-03 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-08-03 00:00:00 due to missing market data
# 2011-08-04 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-08-04 00:00:00 due to missing market data
# 2011-08-05 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-08-05 00:00:00 due to missing market data
# 2011-08-08 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-08-08 00:00:00 due to missing market data
# 2011-08-09 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-08-09 00:00:00 due to missing market data
# 2011-08-10 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-08-10 00:00:00 due to missing market data
# 2011-08-11 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-08-11 00:00:00 due to missing market data
# 2011-08-12 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-08-12 00:00:00 due to missing market data
# 2011-08-15 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-08-15 00:00:00 due to missing market data
# 2011-08-16 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-08-16 00:00:00 due to missing market data
# 2011-08-17 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-08-17 00:00:00 due to missing market data
# 2011-08-18 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-08-18 00:00:00 due to missing market data
# 2011-08-19 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-08-19 00:00:00 due to missing market data
# 2011-08-22 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-08-22 00:00:00 due to missing market data
# 2011-08-23 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-08-23 00:00:00 due to missing market data
# 2011-08-24 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-08-24 00:00:00 due to missing market data
# 2011-08-25 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-08-25 00:00:00 due to missing market data
# 2011-08-26 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-08-26 00:00:00 due to missing market data
# 2011-08-29 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-08-29 00:00:00 due to missing market data
# 2011-08-30 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-08-30 00:00:00 due to missing market data
# 2011-08-31 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-08-31 00:00:00 due to missing market data
# 2011-09-01 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-09-01 00:00:00 due to missing market data
# 2011-09-02 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-09-02 00:00:00 due to missing market data
# 2011-09-06 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-09-06 00:00:00 due to missing market data
# 2011-09-07 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-09-07 00:00:00 due to missing market data
# 2011-09-08 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-09-08 00:00:00 due to missing market data
# 2011-09-09 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-09-09 00:00:00 due to missing market data
# 2011-09-12 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-09-12 00:00:00 due to missing market data
# 2011-09-13 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-09-13 00:00:00 due to missing market data
# 2011-09-14 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-09-14 00:00:00 due to missing market data
# 2011-09-15 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-09-15 00:00:00 due to missing market data
# 2011-09-16 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-09-16 00:00:00 due to missing market data
# 2011-09-19 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-09-19 00:00:00 due to missing market data
# 2011-09-20 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-09-20 00:00:00 due to missing market data
# 2011-09-21 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-09-21 00:00:00 due to missing market data
# 2011-09-22 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-09-22 00:00:00 due to missing market data
# 2011-09-23 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-09-23 00:00:00 due to missing market data
# 2011-09-26 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-09-26 00:00:00 due to missing market data
# 2011-09-27 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-09-27 00:00:00 due to missing market data
# 2011-09-28 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-09-28 00:00:00 due to missing market data
# 2011-09-29 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-09-29 00:00:00 due to missing market data
# 2011-09-30 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-09-30 00:00:00 due to missing market data
# 2011-10-03 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-10-03 00:00:00 due to missing market data
# 2011-10-04 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-10-04 00:00:00 due to missing market data
# 2011-10-05 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-10-05 00:00:00 due to missing market data
# 2011-10-06 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-10-06 00:00:00 due to missing market data
# 2011-10-07 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-10-07 00:00:00 due to missing market data
# 2011-10-10 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-10-10 00:00:00 due to missing market data
# 2011-10-11 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-10-11 00:00:00 due to missing market data
# 2011-10-12 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-10-12 00:00:00 due to missing market data
# 2011-10-13 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-10-13 00:00:00 due to missing market data
# 2011-10-14 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-10-14 00:00:00 due to missing market data
# 2011-10-17 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-10-17 00:00:00 due to missing market data
# 2011-10-18 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-10-18 00:00:00 due to missing market data
# 2011-10-19 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-10-19 00:00:00 due to missing market data
# 2011-10-20 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-10-20 00:00:00 due to missing market data
# 2011-10-21 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-10-21 00:00:00 due to missing market data
# 2011-10-24 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-10-24 00:00:00 due to missing market data
# 2011-10-25 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-10-25 00:00:00 due to missing market data
# 2011-10-26 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-10-26 00:00:00 due to missing market data
# 2011-10-27 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-10-27 00:00:00 due to missing market data
# 2011-10-28 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-10-28 00:00:00 due to missing market data
# 2011-10-31 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-10-31 00:00:00 due to missing market data
# 2011-11-01 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-11-01 00:00:00 due to missing market data
# 2011-11-02 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-11-02 00:00:00 due to missing market data
# 2011-11-03 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-11-03 00:00:00 due to missing market data
# 2011-11-04 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-11-04 00:00:00 due to missing market data
# 2011-11-07 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-11-07 00:00:00 due to missing market data
# 2011-11-08 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-11-08 00:00:00 due to missing market data
# 2011-11-09 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-11-09 00:00:00 due to missing market data
# 2011-11-10 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-11-10 00:00:00 due to missing market data
# 2011-11-11 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-11-11 00:00:00 due to missing market data
# 2011-11-14 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-11-14 00:00:00 due to missing market data
# 2011-11-15 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-11-15 00:00:00 due to missing market data
# 2011-11-16 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-11-16 00:00:00 due to missing market data
# 2011-11-17 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-11-17 00:00:00 due to missing market data
# 2011-11-18 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-11-18 00:00:00 due to missing market data
# 2011-11-21 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-11-21 00:00:00 due to missing market data
# 2011-11-22 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-11-22 00:00:00 due to missing market data
# 2011-11-23 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-11-23 00:00:00 due to missing market data
# 2011-11-25 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-11-25 00:00:00 due to missing market data
# 2011-11-28 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-11-28 00:00:00 due to missing market data
# 2011-11-29 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-11-29 00:00:00 due to missing market data
# 2011-11-30 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-11-30 00:00:00 due to missing market data
# 2011-12-01 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-12-01 00:00:00 due to missing market data
# 2011-12-02 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-12-02 00:00:00 due to missing market data
# 2011-12-05 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-12-05 00:00:00 due to missing market data
# 2011-12-06 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-12-06 00:00:00 due to missing market data
# 2011-12-07 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-12-07 00:00:00 due to missing market data
# 2011-12-08 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-12-08 00:00:00 due to missing market data
# 2011-12-09 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-12-09 00:00:00 due to missing market data
# 2011-12-12 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-12-12 00:00:00 due to missing market data
# 2011-12-13 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-12-13 00:00:00 due to missing market data
# 2011-12-14 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-12-14 00:00:00 due to missing market data
# 2011-12-15 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-12-15 00:00:00 due to missing market data
# 2011-12-16 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-12-16 00:00:00 due to missing market data
# 2011-12-19 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-12-19 00:00:00 due to missing market data
# 2011-12-20 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-12-20 00:00:00 due to missing market data
# 2011-12-21 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-12-21 00:00:00 due to missing market data
# 2011-12-22 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-12-22 00:00:00 due to missing market data
# 2011-12-23 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-12-23 00:00:00 due to missing market data
# 2011-12-27 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-12-27 00:00:00 due to missing market data
# 2011-12-28 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-12-28 00:00:00 due to missing market data
# 2011-12-29 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-12-29 00:00:00 due to missing market data
# 2011-12-30 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2011-12-30 00:00:00 due to missing market data
# 2012-01-03 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2012-01-03 00:00:00 due to missing market data
# 2012-01-04 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2012-01-04 00:00:00 due to missing market data
# 2012-01-05 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2012-01-05 00:00:00 due to missing market data
# 2012-01-06 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2012-01-06 00:00:00 due to missing market data
# 2012-01-09 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2012-01-09 00:00:00 due to missing market data
# 2012-01-10 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2012-01-10 00:00:00 due to missing market data
# 2012-01-11 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2012-01-11 00:00:00 due to missing market data
# 2012-01-12 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2012-01-12 00:00:00 due to missing market data
# 2012-01-13 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2012-01-13 00:00:00 due to missing market data
# 2012-01-17 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2012-01-17 00:00:00 due to missing market data
# 2012-01-18 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2012-01-18 00:00:00 due to missing market data
# 2012-01-19 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2012-01-19 00:00:00 due to missing market data
# 2012-01-20 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2012-01-20 00:00:00 due to missing market data
# 2012-01-23 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2012-01-23 00:00:00 due to missing market data
# 2012-01-24 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2012-01-24 00:00:00 due to missing market data
# 2012-01-25 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2012-01-25 00:00:00 due to missing market data
# 2012-01-26 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2012-01-26 00:00:00 due to missing market data
# 2012-01-27 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2012-01-27 00:00:00 due to missing market data
# 2012-01-30 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2012-01-30 00:00:00 due to missing market data
# 2012-01-31 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2012-01-31 00:00:00 due to missing market data
# 2012-02-01 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2012-02-01 00:00:00 due to missing market data
# 2012-02-02 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2012-02-02 00:00:00 due to missing market data
# 2012-02-03 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2012-02-03 00:00:00 due to missing market data
# 2012-02-06 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2012-02-06 00:00:00 due to missing market data
# 2012-02-07 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2012-02-07 00:00:00 due to missing market data
# 2012-02-08 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2012-02-08 00:00:00 due to missing market data
# 2012-02-09 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2012-02-09 00:00:00 due to missing market data
# 2012-02-10 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2012-02-10 00:00:00 due to missing market data
# 2012-02-13 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2012-02-13 00:00:00 due to missing market data
# 2012-02-14 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2012-02-14 00:00:00 due to missing market data
# 2012-02-15 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2012-02-15 00:00:00 due to missing market data
# 2012-02-16 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2012-02-16 00:00:00 due to missing market data
# 2012-02-17 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2012-02-17 00:00:00 due to missing market data
# 2012-02-21 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2012-02-21 00:00:00 due to missing market data
# 2012-02-22 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2012-02-22 00:00:00 due to missing market data
# 2012-02-23 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2012-02-23 00:00:00 due to missing market data
# 2012-02-24 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2012-02-24 00:00:00 due to missing market data
# 2012-02-27 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2012-02-27 00:00:00 due to missing market data
# 2012-02-28 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2012-02-28 00:00:00 due to missing market data
# 2012-02-29 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2012-02-29 00:00:00 due to missing market data
# 2012-03-01 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2012-03-01 00:00:00 due to missing market data
# 2012-03-02 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2012-03-02 00:00:00 due to missing market data
# 2012-03-05 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2012-03-05 00:00:00 due to missing market data
# 2012-03-06 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2012-03-06 00:00:00 due to missing market data
# 2012-03-07 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2012-03-07 00:00:00 due to missing market data
# 2012-03-08 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2012-03-08 00:00:00 due to missing market data
# 2012-03-09 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2012-03-09 00:00:00 due to missing market data
# 2012-03-12 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2012-03-12 00:00:00 due to missing market data
# 2012-03-13 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2012-03-13 00:00:00 due to missing market data
# 2012-03-14 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2012-03-14 00:00:00 due to missing market data
# 2012-03-15 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2012-03-15 00:00:00 due to missing market data
# 2012-03-16 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2012-03-16 00:00:00 due to missing market data
# 2012-03-19 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2012-03-19 00:00:00 due to missing market data
# 2012-03-20 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2012-03-20 00:00:00 due to missing market data
# 2012-03-21 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2012-03-21 00:00:00 due to missing market data
# 2012-03-22 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2012-03-22 00:00:00 due to missing market data
# 2012-03-23 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2012-03-23 00:00:00 due to missing market data
# 2012-03-26 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2012-03-26 00:00:00 due to missing market data
# 2012-03-27 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2012-03-27 00:00:00 due to missing market data
# 2012-03-28 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2012-03-28 00:00:00 due to missing market data
# 2012-03-29 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2012-03-29 00:00:00 due to missing market data
# 2012-03-30 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2012-03-30 00:00:00 due to missing market data
# 2012-04-02 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2012-04-02 00:00:00 due to missing market data
# 2012-04-03 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2012-04-03 00:00:00 due to missing market data
# 2012-04-04 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2012-04-04 00:00:00 due to missing market data
# 2012-04-05 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2012-04-05 00:00:00 due to missing market data
# 2012-04-09 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2012-04-09 00:00:00 due to missing market data
# 2012-04-10 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2012-04-10 00:00:00 due to missing market data
# 2012-04-11 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2012-04-11 00:00:00 due to missing market data
# 2012-04-12 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2012-04-12 00:00:00 due to missing market data
# 2012-04-13 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2012-04-13 00:00:00 due to missing market data
# 2012-04-16 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2012-04-16 00:00:00 due to missing market data
# 2012-04-17 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2012-04-17 00:00:00 due to missing market data
# 2012-04-18 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2012-04-18 00:00:00 due to missing market data
# 2012-04-19 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2012-04-19 00:00:00 due to missing market data
# 2012-04-20 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2012-04-20 00:00:00 due to missing market data
# 2012-04-23 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2012-04-23 00:00:00 due to missing market data
# 2012-04-24 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2012-04-24 00:00:00 due to missing market data
# 2012-04-25 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2012-04-25 00:00:00 due to missing market data
# 2012-04-26 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2012-04-26 00:00:00 due to missing market data
# 2012-04-27 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2012-04-27 00:00:00 due to missing market data
# 2012-04-30 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2012-04-30 00:00:00 due to missing market data
# 2012-05-01 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2012-05-01 00:00:00 due to missing market data
# 2012-05-02 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2012-05-02 00:00:00 due to missing market data
# 2012-05-03 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2012-05-03 00:00:00 due to missing market data
# 2012-05-04 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2012-05-04 00:00:00 due to missing market data
# 2012-05-07 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2012-05-07 00:00:00 due to missing market data
# 2012-05-08 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2012-05-08 00:00:00 due to missing market data
# 2012-05-09 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2012-05-09 00:00:00 due to missing market data
# 2012-05-10 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2012-05-10 00:00:00 due to missing market data
# 2012-05-11 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2012-05-11 00:00:00 due to missing market data
# 2012-05-14 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2012-05-14 00:00:00 due to missing market data
# 2012-05-15 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2012-05-15 00:00:00 due to missing market data
# 2012-05-16 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2012-05-16 00:00:00 due to missing market data
# 2012-05-17 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2012-05-17 00:00:00 due to missing market data
# 2012-05-18 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2012-05-18 00:00:00 due to missing market data
# 2012-05-21 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2012-05-21 00:00:00 due to missing market data
# 2012-05-22 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2012-05-22 00:00:00 due to missing market data
# 2012-05-23 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2012-05-23 00:00:00 due to missing market data
# 2012-05-24 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2012-05-24 00:00:00 due to missing market data
# 2012-05-25 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2012-05-25 00:00:00 due to missing market data
# 2012-05-29 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2012-05-29 00:00:00 due to missing market data
# 2012-05-30 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2012-05-30 00:00:00 due to missing market data
# 2012-05-31 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2012-05-31 00:00:00 due to missing market data
# 2012-06-01 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2012-06-01 00:00:00 due to missing market data
# 2012-06-04 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2012-06-04 00:00:00 due to missing market data
# 2012-06-05 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2012-06-05 00:00:00 due to missing market data
# 2012-06-06 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2012-06-06 00:00:00 due to missing market data
# 2012-06-07 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2012-06-07 00:00:00 due to missing market data
# 2012-06-08 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2012-06-08 00:00:00 due to missing market data
# 2012-06-11 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2012-06-11 00:00:00 due to missing market data
# 2012-06-12 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2012-06-12 00:00:00 due to missing market data
# 2012-06-13 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2012-06-13 00:00:00 due to missing market data
# 2012-06-14 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2012-06-14 00:00:00 due to missing market data
# 2012-06-15 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2012-06-15 00:00:00 due to missing market data
# 2012-06-18 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2012-06-18 00:00:00 due to missing market data
# 2012-06-19 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2012-06-19 00:00:00 due to missing market data
# 2012-06-20 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2012-06-20 00:00:00 due to missing market data
# 2012-06-21 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2012-06-21 00:00:00 due to missing market data
# 2012-06-22 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2012-06-22 00:00:00 due to missing market data
# 2012-06-25 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2012-06-25 00:00:00 due to missing market data
# 2012-06-26 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2012-06-26 00:00:00 due to missing market data
# 2012-06-27 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2012-06-27 00:00:00 due to missing market data
# 2012-06-28 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2012-06-28 00:00:00 due to missing market data
# 2012-06-29 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2012-06-29 00:00:00 due to missing market data
# 2012-07-02 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2012-07-02 00:00:00 due to missing market data
# 2012-07-03 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2012-07-03 00:00:00 due to missing market data
# 2012-07-05 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2012-07-05 00:00:00 due to missing market data
# 2012-07-06 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2012-07-06 00:00:00 due to missing market data
# 2012-07-09 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2012-07-09 00:00:00 due to missing market data
# 2012-07-10 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2012-07-10 00:00:00 due to missing market data
# 2012-07-11 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2012-07-11 00:00:00 due to missing market data
# 2012-07-12 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2012-07-12 00:00:00 due to missing market data
# 2012-07-13 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2012-07-13 00:00:00 due to missing market data
# 2012-07-16 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2012-07-16 00:00:00 due to missing market data
# 2012-07-17 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2012-07-17 00:00:00 due to missing market data
# 2012-07-18 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2012-07-18 00:00:00 due to missing market data
# 2012-07-19 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2012-07-19 00:00:00 due to missing market data
# 2012-07-20 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2012-07-20 00:00:00 due to missing market data
# 2012-07-23 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2012-07-23 00:00:00 due to missing market data
# 2012-07-24 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2012-07-24 00:00:00 due to missing market data
# 2012-07-25 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2012-07-25 00:00:00 due to missing market data
# 2012-07-26 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2012-07-26 00:00:00 due to missing market data
# 2012-07-27 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2012-07-27 00:00:00 due to missing market data
# 2012-07-30 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2012-07-30 00:00:00 due to missing market data
# 2012-07-31 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2012-07-31 00:00:00 due to missing market data
# 2012-08-01 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2012-08-01 00:00:00 due to missing market data
# 2012-08-02 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2012-08-02 00:00:00 due to missing market data
# 2012-08-03 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2012-08-03 00:00:00 due to missing market data
# 2012-08-06 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2012-08-06 00:00:00 due to missing market data
# 2012-08-07 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2012-08-07 00:00:00 due to missing market data
# 2012-08-08 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2012-08-08 00:00:00 due to missing market data
# 2012-08-09 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2012-08-09 00:00:00 due to missing market data
# 2012-08-10 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2012-08-10 00:00:00 due to missing market data
# 2012-08-13 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2012-08-13 00:00:00 due to missing market data
# 2012-08-14 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2012-08-14 00:00:00 due to missing market data
# 2012-08-15 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2012-08-15 00:00:00 due to missing market data
# 2012-08-16 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2012-08-16 00:00:00 due to missing market data
# 2012-08-17 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2012-08-17 00:00:00 due to missing market data
# 2012-08-20 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2012-08-20 00:00:00 due to missing market data
# 2012-08-21 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2012-08-21 00:00:00 due to missing market data
# 2012-08-22 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2012-08-22 00:00:00 due to missing market data
# 2012-08-23 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2012-08-23 00:00:00 due to missing market data
# 2012-08-24 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2012-08-24 00:00:00 due to missing market data
# 2012-08-27 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2012-08-27 00:00:00 due to missing market data
# 2012-08-28 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2012-08-28 00:00:00 due to missing market data
# 2012-08-29 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2012-08-29 00:00:00 due to missing market data
# 2012-08-30 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2012-08-30 00:00:00 due to missing market data
# 2012-08-31 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2012-08-31 00:00:00 due to missing market data
# 2012-09-04 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2012-09-04 00:00:00 due to missing market data
# 2012-09-05 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2012-09-05 00:00:00 due to missing market data
# 2012-09-06 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2012-09-06 00:00:00 due to missing market data
# ...
# ⚠️ Skipping 2024-10-31 00:00:00 due to missing market data
# 2024-11-01 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2024-11-01 00:00:00 due to missing market data
# 2024-11-04 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2024-11-04 00:00:00 due to missing market data
# 2024-11-05 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2024-11-05 00:00:00 due to missing market data
# 2024-11-06 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2024-11-06 00:00:00 due to missing market data
# 2024-11-07 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2024-11-07 00:00:00 due to missing market data
# 2024-11-08 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2024-11-08 00:00:00 due to missing market data
# 2024-11-11 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2024-11-11 00:00:00 due to missing market data
# 2024-11-12 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2024-11-12 00:00:00 due to missing market data
# 2024-11-13 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2024-11-13 00:00:00 due to missing market data
# 2024-11-14 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2024-11-14 00:00:00 due to missing market data
# 2024-11-15 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2024-11-15 00:00:00 due to missing market data
# 2024-11-18 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2024-11-18 00:00:00 due to missing market data
# 2024-11-19 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2024-11-19 00:00:00 due to missing market data
# 2024-11-20 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2024-11-20 00:00:00 due to missing market data
# 2024-11-21 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2024-11-21 00:00:00 due to missing market data
# 2024-11-22 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2024-11-22 00:00:00 due to missing market data
# 2024-11-25 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2024-11-25 00:00:00 due to missing market data
# 2024-11-26 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2024-11-26 00:00:00 due to missing market data
# 2024-11-27 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2024-11-27 00:00:00 due to missing market data
# 2024-11-29 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2024-11-29 00:00:00 due to missing market data
# 2024-12-02 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2024-12-02 00:00:00 due to missing market data
# 2024-12-03 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2024-12-03 00:00:00 due to missing market data
# 2024-12-04 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2024-12-04 00:00:00 due to missing market data
# 2024-12-05 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2024-12-05 00:00:00 due to missing market data
# 2024-12-06 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2024-12-06 00:00:00 due to missing market data
# 2024-12-09 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2024-12-09 00:00:00 due to missing market data
# 2024-12-10 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2024-12-10 00:00:00 due to missing market data
# 2024-12-11 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2024-12-11 00:00:00 due to missing market data
# 2024-12-12 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2024-12-12 00:00:00 due to missing market data
# 2024-12-13 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2024-12-13 00:00:00 due to missing market data
# 2024-12-16 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2024-12-16 00:00:00 due to missing market data
# 2024-12-17 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2024-12-17 00:00:00 due to missing market data
# 2024-12-18 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2024-12-18 00:00:00 due to missing market data
# 2024-12-19 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2024-12-19 00:00:00 due to missing market data
# 2024-12-20 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2024-12-20 00:00:00 due to missing market data
# 2024-12-23 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2024-12-23 00:00:00 due to missing market data
# 2024-12-24 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2024-12-24 00:00:00 due to missing market data
# 2024-12-26 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2024-12-26 00:00:00 due to missing market data
# 2024-12-27 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2024-12-27 00:00:00 due to missing market data
# 2024-12-30 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2024-12-30 00:00:00 due to missing market data
# 2024-12-31 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2024-12-31 00:00:00 due to missing market data
# 2025-01-02 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2025-01-02 00:00:00 due to missing market data
# 2025-01-03 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2025-01-03 00:00:00 due to missing market data
# 2025-01-06 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2025-01-06 00:00:00 due to missing market data
# 2025-01-07 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2025-01-07 00:00:00 due to missing market data
# 2025-01-08 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2025-01-08 00:00:00 due to missing market data
# 2025-01-10 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2025-01-10 00:00:00 due to missing market data
# 2025-01-13 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2025-01-13 00:00:00 due to missing market data
# 2025-01-14 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2025-01-14 00:00:00 due to missing market data
# 2025-01-15 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2025-01-15 00:00:00 due to missing market data
# 2025-01-16 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2025-01-16 00:00:00 due to missing market data
# 2025-01-17 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2025-01-17 00:00:00 due to missing market data
# 2025-01-21 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2025-01-21 00:00:00 due to missing market data
# 2025-01-22 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2025-01-22 00:00:00 due to missing market data
# 2025-01-23 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2025-01-23 00:00:00 due to missing market data
# 2025-01-24 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2025-01-24 00:00:00 due to missing market data
# 2025-01-27 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2025-01-27 00:00:00 due to missing market data
# 2025-01-28 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2025-01-28 00:00:00 due to missing market data
# 2025-01-29 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2025-01-29 00:00:00 due to missing market data
# 2025-01-30 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2025-01-30 00:00:00 due to missing market data
# 2025-01-31 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2025-01-31 00:00:00 due to missing market data
# 2025-02-03 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2025-02-03 00:00:00 due to missing market data
# 2025-02-04 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2025-02-04 00:00:00 due to missing market data
# 2025-02-05 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2025-02-05 00:00:00 due to missing market data
# 2025-02-06 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2025-02-06 00:00:00 due to missing market data
# 2025-02-07 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2025-02-07 00:00:00 due to missing market data
# 2025-02-10 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2025-02-10 00:00:00 due to missing market data
# 2025-02-11 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2025-02-11 00:00:00 due to missing market data
# 2025-02-12 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2025-02-12 00:00:00 due to missing market data
# 2025-02-13 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2025-02-13 00:00:00 due to missing market data
# 2025-02-14 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2025-02-14 00:00:00 due to missing market data
# 2025-02-18 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2025-02-18 00:00:00 due to missing market data
# 2025-02-19 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2025-02-19 00:00:00 due to missing market data
# 2025-02-20 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2025-02-20 00:00:00 due to missing market data
# 2025-02-21 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2025-02-21 00:00:00 due to missing market data
# 2025-02-24 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2025-02-24 00:00:00 due to missing market data
# 2025-02-25 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2025-02-25 00:00:00 due to missing market data
# 2025-02-26 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2025-02-26 00:00:00 due to missing market data
# 2025-02-27 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2025-02-27 00:00:00 due to missing market data
# 2025-02-28 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2025-02-28 00:00:00 due to missing market data
# 2025-03-03 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2025-03-03 00:00:00 due to missing market data
# 2025-03-04 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2025-03-04 00:00:00 due to missing market data
# 2025-03-05 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2025-03-05 00:00:00 due to missing market data
# 2025-03-06 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2025-03-06 00:00:00 due to missing market data
# 2025-03-07 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2025-03-07 00:00:00 due to missing market data
# 2025-03-10 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2025-03-10 00:00:00 due to missing market data
# 2025-03-11 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2025-03-11 00:00:00 due to missing market data
# 2025-03-12 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2025-03-12 00:00:00 due to missing market data
# 2025-03-13 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2025-03-13 00:00:00 due to missing market data
# 2025-03-14 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2025-03-14 00:00:00 due to missing market data
# 2025-03-17 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2025-03-17 00:00:00 due to missing market data
# 2025-03-18 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2025-03-18 00:00:00 due to missing market data
# 2025-03-19 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2025-03-19 00:00:00 due to missing market data
# 2025-03-20 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2025-03-20 00:00:00 due to missing market data
# 2025-03-21 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2025-03-21 00:00:00 due to missing market data
# 2025-03-24 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2025-03-24 00:00:00 due to missing market data
# 2025-03-25 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2025-03-25 00:00:00 due to missing market data
# 2025-03-26 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2025-03-26 00:00:00 due to missing market data
# 2025-03-27 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2025-03-27 00:00:00 due to missing market data
# 2025-03-28 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2025-03-28 00:00:00 due to missing market data
# 2025-03-31 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2025-03-31 00:00:00 due to missing market data
# 2025-04-01 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2025-04-01 00:00:00 due to missing market data
# 2025-04-02 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2025-04-02 00:00:00 due to missing market data
# 2025-04-03 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2025-04-03 00:00:00 due to missing market data
# 2025-04-04 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2025-04-04 00:00:00 due to missing market data
# 2025-04-07 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2025-04-07 00:00:00 due to missing market data
# 2025-04-08 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2025-04-08 00:00:00 due to missing market data
# 2025-04-09 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2025-04-09 00:00:00 due to missing market data
# 2025-04-10 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2025-04-10 00:00:00 due to missing market data
# 2025-04-11 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2025-04-11 00:00:00 due to missing market data
# 2025-04-14 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2025-04-14 00:00:00 due to missing market data
# 2025-04-15 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2025-04-15 00:00:00 due to missing market data
# 2025-04-16 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2025-04-16 00:00:00 due to missing market data
# 2025-04-17 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2025-04-17 00:00:00 due to missing market data
# 2025-04-21 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2025-04-21 00:00:00 due to missing market data
# 2025-04-22 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2025-04-22 00:00:00 due to missing market data
# 2025-04-23 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2025-04-23 00:00:00 due to missing market data
# 2025-04-24 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2025-04-24 00:00:00 due to missing market data
# 2025-04-25 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2025-04-25 00:00:00 due to missing market data
# 2025-04-28 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2025-04-28 00:00:00 due to missing market data
# 2025-04-29 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2025-04-29 00:00:00 due to missing market data
# 2025-04-30 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2025-04-30 00:00:00 due to missing market data
# 2025-05-01 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2025-05-01 00:00:00 due to missing market data
# 2025-05-02 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2025-05-02 00:00:00 due to missing market data
# 2025-05-05 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2025-05-05 00:00:00 due to missing market data
# 2025-05-06 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2025-05-06 00:00:00 due to missing market data
# 2025-05-07 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2025-05-07 00:00:00 due to missing market data
# Simulating for each date: 100%|██████████| 3597/3597 [00:00<00:00, 4042.61it/s]
# 2025-05-08 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2025-05-08 00:00:00 due to missing market data
# 2025-05-09 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2025-05-09 00:00:00 due to missing market data
# 2025-05-12 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2025-05-12 00:00:00 due to missing market data
# 2025-05-13 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2025-05-13 00:00:00 due to missing market data
# 2025-05-14 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2025-05-14 00:00:00 due to missing market data
# 2025-05-15 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2025-05-15 00:00:00 due to missing market data
# 2025-05-16 00:00:00
# RangeIndex(start=0, stop=4857, step=1)
# ⚠️ Skipping 2025-05-16 00:00:00 due to missing market data
# ❌ No simulation results generated.

# %%
historic_data.head()
# Out:
#         Date    Price        IV  Risk_Free       Div  Actinver_Expected_Return
# 0 2006-01-27  1283.72  0.136327   0.044105  0.018607                  0.116700
# 1 2006-01-30  1285.20  0.136373   0.044257  0.018424                  0.117329
# 2 2006-01-31  1280.09  0.138087   0.044162  0.019291                  0.122860
# 3 2006-02-01  1282.46  0.137092   0.044544  0.018838                  0.121704
# 4 2006-02-02  1270.84  0.140062   0.044563  0.018784                  0.132723

# %% [markdown]
# ## Miscellaneous

# %%
blue_palette = sns.color_palette("Blues", n_colors=10)

# %%
blue_palette

# %%
# Blended for the number of paths
actinver_palette_blended = blend_palette(ACTINVER_BLUES, n_colors=10)

# %%
actinver_palette_blended
